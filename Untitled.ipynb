# %%
import os
import numpy as np
import json
from keras.preprocessing import image
from keras.models import load_model
import tensorflow as tf
from flask import Flask,request,render_template
from werkzeug.utils import secure_filename
from tensorflow.keras.models import Sequential
from keras.models import model_from_json
from __future__ import division, print_function
from PIL import Image

# %%
# json_model_path=r"./final_model/final_model.json"
# h5_model_path=r"./final_model/final_model.h5"
# json_file = open(json_model_path, 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# loaded_model = tf.keras.models.load_model(h5_model_path)

json_path=r"./final_model/final_model.json"
json_file=open(json_path,'r')
loaded_model_json=json_file.read()
json_file.close()
h5_path=r"./final_model/final_model.h5"
loaded_model=model_from_json(loaded_model_json)
loaded_model.load_weights(h5_path)

# %%
img_path = r"./static/uploads/images (1).jpg"
img=Image.open(img_path)
img=img.resize((256,256),Image.ANTIALIAS)
# Out:
# /var/folders/hp/1_n_23v10813bhp384tgjp5m0000gn/T/ipykernel_41545/1602522496.py:3: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img=img.resize((256,256),Image.ANTIALIAS)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img=np.array(img)

# %%
found=['Great Indian Bustard Bird','Spoon Billed Sandpiper Bird','Corpse Flower','Lady Slipper Orchid Flower','Pangolin Mammal','Senenca White Deer Mammal']
# predictions = loaded_model.predict_proba([img.reshape(1, 256,256,3)])

# for idx, result, x in zip(range(0,6), found, predictions[0]): 
#     print("Label: {}, Type: {}, Species: {}, Score: {}%".format(idx, result[0],result[1], round(x*100,3)))

predict_x=loaded_model.predict([img.reshape(1,256,256,3)]) 
classes_x=np.argmax(predict_x,axis=0)
print (found[classes_x[0]])
# Out:
# 2022-11-17 13:56:05.920350: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 2s 2s/step
# Great Indian Bustard Bird
